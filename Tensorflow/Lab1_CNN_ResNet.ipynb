# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers

nb_classes = 10
(train_x, train_y), (test_x, test_y) = keras.datasets.cifar10.load_data()
train_x, test_x = train_x / 255.0, test_x / 255.0

train_y = keras.utils.to_categorical(train_y, nb_classes)
test_y = keras.utils.to_categorical(test_y, nb_classes)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step

# %%
class Block(keras.layers.Layer):
  def __init__(self, f1, f2, s):
    super().__init__()
    kernel_initializer = 'he_normal'
    self.strides = s
    
    self.layers = keras.Sequential([
      # implement here
    ])
    
  def call(self, inputs):
    # implement here
    x = self.layers(inputs)
    return x

class Network(keras.Model):
  def __init__(self):
    super().__init__()
    self.kernel_initializer = 'he_normal'
  
  def build(self, input_shape): # automatically called when first __call__ invokes.
    self.first_layer = keras.Sequential([
      layers.Conv2D(filters=16, kernel_size=3, strides=1, padding='same', kernel_initializer=self.kernel_initializer),
      layers.ReLU()
    ])
    
    # implement blocks here
    # using for() can make code short
    
    self.last_layer = keras.Sequential([
      layers.GlobalAveragePooling2D(),
      layers.Flatten(),
      layers.Dense(10, kernel_initializer=self.kernel_initializer)
    ])

  def call(self, inputs): # automatically called in __call__ after build().
    x = self.first_layer(inputs)
    
    #implement blocks call here

    x = self.last_layer(x)
    return x

model = Network()
model.compile(loss=keras.losses.CategoricalCrossentropy(from_logits=True),
              optimizer=keras.optimizers.Adam(0.005),
              metrics=['accuracy'])

epoch = 7
batch_size = 128
model.fit(x=train_x, y=train_y, batch_size=batch_size, epochs=epoch, validation_data=(test_x, test_y))
# Out:
# Epoch 1/7
# 391/391 [==============================] - 26s 31ms/step - loss: 1.4879 - accuracy: 0.4472 - val_loss: 15.4184 - val_accuracy: 0.2333
# Epoch 2/7
# 391/391 [==============================] - 11s 29ms/step - loss: 1.0440 - accuracy: 0.6226 - val_loss: 3.9750 - val_accuracy: 0.3220
# Epoch 3/7
# 391/391 [==============================] - 12s 30ms/step - loss: 0.8572 - accuracy: 0.6968 - val_loss: 5.6718 - val_accuracy: 0.2789
# Epoch 4/7
# 391/391 [==============================] - 11s 28ms/step - loss: 0.7374 - accuracy: 0.7416 - val_loss: 0.9890 - val_accuracy: 0.6842
# Epoch 5/7
# 391/391 [==============================] - 11s 29ms/step - loss: 0.6623 - accuracy: 0.7698 - val_loss: 0.8006 - val_accuracy: 0.7320
# Epoch 6/7
# 391/391 [==============================] - 11s 28ms/step - loss: 0.5923 - accuracy: 0.7932 - val_loss: 1.6385 - val_accuracy: 0.5922
# Epoch 7/7
# 391/391 [==============================] - 11s 28ms/step - loss: 0.5363 - accuracy: 0.8143 - val_loss: 0.8876 - val_accuracy: 0.7254

# %%
class ResNetBlock(keras.layers.Layer):
  def __init__(self, f1, f2, s):
    super().__init__()
    kernel_initializer = 'he_normal'
    self.strides = s
    
    self.residual = keras.Sequential([
      # implement here
      ])
    
    if self.strides == 2:
      self.shortcut_conv = keras.Sequential([
      # implement here
      ])

  def call(self, inputs):
    if self.strides == 2:
      shortcut = self.shortcut_conv(inputs)
    else:
      shortcut = inputs
    
    # implement here

    return x
    
class ResNet(keras.Model):
  def __init__(self):
    super().__init__()
    self.kernel_initializer = 'he_normal'
  
  def build(self, input_shape): # automatically called when first __call__ invokes.
    self.first_layer = keras.Sequential([
      layers.Conv2D(filters=16, kernel_size=3, strides=1, padding='same', kernel_initializer=self.kernel_initializer),
      layers.BatchNormalization(),
      layers.ReLU()
    ])

    # implement blocks here
    # using for() can make code short

    self.last_layer = keras.Sequential([
      layers.GlobalAveragePooling2D(),
      layers.Flatten(),
      layers.Dense(10, kernel_initializer=self.kernel_initializer)
    ])

  def call(self, inputs): # automatically called in __call__ after build().
    x = self.first_layer(inputs)
    
     #implement blocks call here

    x = self.last_layer(x)
    return x
    
model = ResNet()
model.compile(loss=keras.losses.CategoricalCrossentropy(from_logits=True),
              optimizer=keras.optimizers.Adam(0.001),
              metrics=['accuracy'])

epoch = 7
batch_size = 128
model.fit(x=train_x, y=train_y, batch_size=batch_size, epochs=epoch, validation_data=(test_x, test_y))
# Out:
# Epoch 1/7
# 391/391 [==============================] - 17s 34ms/step - loss: 1.4172 - accuracy: 0.4806 - val_loss: 1.6209 - val_accuracy: 0.4683
# Epoch 2/7
# 391/391 [==============================] - 12s 31ms/step - loss: 1.0328 - accuracy: 0.6301 - val_loss: 1.0834 - val_accuracy: 0.6081
# Epoch 3/7
# 391/391 [==============================] - 13s 32ms/step - loss: 0.8407 - accuracy: 0.7028 - val_loss: 1.1677 - val_accuracy: 0.6083
# Epoch 4/7
# 391/391 [==============================] - 12s 32ms/step - loss: 0.7138 - accuracy: 0.7483 - val_loss: 0.8123 - val_accuracy: 0.7245
# Epoch 5/7
# 391/391 [==============================] - 12s 31ms/step - loss: 0.6132 - accuracy: 0.7848 - val_loss: 0.9949 - val_accuracy: 0.6714
# Epoch 6/7
# 391/391 [==============================] - 13s 32ms/step - loss: 0.5341 - accuracy: 0.8133 - val_loss: 1.0155 - val_accuracy: 0.6656
# Epoch 7/7
# 391/391 [==============================] - 13s 34ms/step - loss: 0.4668 - accuracy: 0.8386 - val_loss: 1.1402 - val_accuracy: 0.6559

# %%
# !nvidia-smi
# Out:
# Fri Aug 19 13:18:50 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 451.67       Driver Version: 451.67       CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 207... WDDM  | 00000000:01:00.0  On |                  N/A |
# | N/A   41C    P8    10W /  N/A |   1332MiB /  8192MiB |     28%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1276    C+G   Insufficient Permissions        N/A      |
# |    0   N/A  N/A      1560    C+G   ...cw5n1h2txyewy\LockApp.exe    N/A      |
# |    0   N/A  N/A      3092    C+G   ...wekyb3d8bbwe\Video.UI.exe    N/A      |
# |    0   N/A  N/A      3280    C+G   ...y\ShellExperienceHost.exe    N/A      |
# |    0   N/A  N/A      3668    C+G   C:\Windows\explorer.exe         N/A      |
# |    0   N/A  N/A      4984    C+G   ...Roaming\Zoom\bin\Zoom.exe    N/A      |
# |    0   N/A  N/A      7756    C+G   ...icrosoft VS Code\Code.exe    N/A      |
# |    0   N/A  N/A      8648    C+G   ...5n1h2txyewy\SearchApp.exe    N/A      |
# |    0   N/A  N/A      9312    C+G   ...bbwe\Microsoft.Photos.exe    N/A      |
# |    0   N/A  N/A      9756    C+G   ...lPanel\SystemSettings.exe    N/A      |
# |    0   N/A  N/A      9880    C+G   ...5n1h2txyewy\SearchApp.exe    N/A      |
# |    0   N/A  N/A     10712    C+G   ...ekyb3d8bbwe\YourPhone.exe    N/A      |
# |    0   N/A  N/A     12776    C+G   ...ge\Application\msedge.exe    N/A      |
# |    0   N/A  N/A     13232    C+G   ...8wekyb3d8bbwe\Cortana.exe    N/A      |
# |    0   N/A  N/A     13776    C+G   ...2txyewy\TextInputHost.exe    N/A      |
# |    0   N/A  N/A     15464    C+G   ...ming\Zoom\bin\CptHost.exe    N/A      |
# +-----------------------------------------------------------------------------+
